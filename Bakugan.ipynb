# %%
import re
import numpy as np
import matplotlib.pyplot as plt

## TO DO: Implement Game loop

## We use B-Power as analogus to G-power
class Bakugan:
  ## We set damage to 0 for default purposes, this would later check if we decided to use BBP 
  def __init__(self,name,b_power,attribute,damage=0):
    self.name=name
    self.b_power=b_power
    self.attribute=attribute
    self.damage=damage
  
  #@property
  #def get_name(self):
    #return self.name
  def get_name(self):
    #print(self.name)
    return self.name
  def get_attribute(self):
    return self.attribute
  def get_b_power(self):
    return self.b_power
  
  def get_damage(self):
    return self.damage
  #def get_b_power(self):
    #return self.b_power
  def set_name(self,name):
    self.name=name
  def set_b_power(self,b_power):
    self.b_power=b_power
  #def attribute(self):
    #return self.attribute
  def set_attribute(self,attribute):
    self.attribute=attribute
    
  def set_damage(self,damage):
    self.damage=damage
  #def name(self,name):
    #self.name=name
  def increment_b(self,increment_factor):
      self.b_power+=increment_factor
      return self.b_power
  #def b_power(self,b_power):
    #self.b_power=b_power
  def decrement_b(self,decrement_factor):
    self.b_power-=decrement_factor
    return self.b_power
  
  def increment_damage(self,increment_factor):
    self.damage+=increment_factor
  
  def decrement_damage(self,decrement_factor):
    self.damage-=decrement_factor
  
 
  
  
  #def attribute(self,attribute):
    #self.attribute=attribute
    
  #def display()
    
## Round 1:
## Some possible plans of attack
## Have a dictionary to store the different type of effects based 
## on substring match
## Use a SQL database or write the effects down in a .csv file and maintain 

## Round 2: 
## Yeah OK on second thought this looks messy time for a class design rewrite
## The refactored class can be found below this one i.e below class Card
class Card:
  def __init__(self,description,card_type,
               energy_cost,paired_bakucores,base_bakugan,b_power,
               damage,effect):
    self.description=description
    self.card_type=card_type
    self.energy_cost=energy_cost
    self.paired_bakucores=paired_bakucores
    self.base_bakugan=base_bakugan
    self.b_power=b_power
    self.damage=damage
    self.effect=effect
    
    def get_description(self):
      return self.description
    def set_description(self,description):
      self.description=description
    
    def get_card_type(self):
      return self.card_type
    def set_card_type(self,card_type):
      self.card_type=card_type
      
    def get_energy_cost(self):
      return self.energy_cost
    def set_energy_cost(self,energy_cost):
      self.energy_cost=energy_cost
    
    def get_paired_bakucores(self):
      return self.paired_bakucores
    def set_paired_bakucores(self,paired_bakucores):
      self.paired_bakucores=paired_bakucores
    
    def get_base_bakugan(self):
      return self.base_bakugan
    def set_base_bakugan(self,base_bakugan):
      self.base_bakugan=base_bakugan
    
    def get_b_power(self):
      return self.b_power
    def set_b_power(self,b_power):
      self.b_power=b_power
      
    def get_damage(self):
      return self.damage
    def set_damage(self,damage):
      self.damage=damage
    
    def get_effect(self):
      return self.effect
    def set_effect(self,effect):
      self.effect=effect
      

## Kado is Card in Japanese
class Kado:
  def __init__(self,name,attribute="",description=""):
    self.description=description
    self.name=name
    self.attribute=attribute
  
  def get_name(self):
    return self.name
  def set_name(self,name):
    self.name=name
  
  def get_attribute(self):
    return self.attribute
  def set_attribute(self,attribute):
    self.attribute=attribute
  def get_description(self):
    return self.description
  def set_description(self,description):
    self.description=description
  
  
  
  

## Subtract cards are cards that subtract G-power off a Bakugan
## Our attributes of this class are as follows the attributes inherited
## from the Kado class and a boolean flag that indicates True if it affects the opponent
## False if it affects the players 
## Subtract factor denotes how much G power to subtract from a particular Bakugan
class Subtract(Kado):
  def __init__(self,name,attribute,description,subtract_factor,on_opponent):
    super().__init__(name,attribute,description)
    self.subtract_factor=subtract_factor
    self.on_opponent=on_opponent
    
  def get_subtract_factor(self):
    return self.subtract_factor
  
  def set_subtract_factor(self,subtract_factor):
    
    
     
    


    

class Player:
  def __init__(self,name,bakugan,card_list):
    
    self.bakugan=bakugan
    self.card_list=card_list
    


    
    




print("Time to test out some classes: ")

helios=Bakugan("Helios",300,"Nova")

print(type(helios))

print(":: Testing getter functions ::")

print("The name of our Bakugan object is: ",helios.get_name())
print("The b power: ",helios.get_b_power())
print("The attribute of our Bakugan is: ",helios.get_attribute())
print("The damage of our Bakugan is", helios.get_damage())

p1Card=Kado("Dragon Contender","","Returns the opponent's G-Power to its base level and adds 600 Gs to Drago")
print("The Name of our ability card is:  ",p1Card.get_name())
print("The attribute on our ability card is: ",p1Card.get_attribute())
print("The Description on that card is: ",p1Card.get_description())

print("Testing inheritence ")
## __init__(name,atttribute,description,subtract_factor,on_opponent):
Dragon_Contender=Subtract(p1Card.get_name(),p1Card.get_attribute(),p1Card.get_description(),helios.get_b_power(),True)
print(Dragon_Contender.get_name())
#print("The ")






#helios.get_name()
#helios.get_b_power()
#helios.set_name("Heriousu")
#helios.get_name()
#helios.set_b_power(300)
#helios.get_b_power()
#helios.set_attribute("Pyrus")
#helios.get_attribute()
#print(helios.name)
#helios.name("Helios")
#helios.increment_b(10)
#helios.get_b_power()
#helios.get_name()
#f=helios.get_b_power()
#print(type(f))
#h=helios.decrement_b(30)
#print(h)
#helios.get_damage()
# Out:
# Time to test out some classes:
# <class '__main__.Bakugan'>
# :: Testing getter functions ::
# The name of our Bakugan object is:  Helios
# The b power:  300
# The attribute of our Bakugan is:  Nova
# The damage of our Bakugan is 0
# The Name of our ability card is:   Dragon Contender
# The attribute on our ability card is:
# The Description on that card is:  Returns the opponent's G-Power to its base level and adds 600 Gs to Drago
# Testing inheritence
# Dragon Contender
